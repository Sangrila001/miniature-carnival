# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangrila001/miniature-carnival/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("Hello World")
# Out:
# Hello World

# %%
x=150
print(x)
# Out:
# 150

# %%
x = 50
y = 15
print(x+y)
# Out:
# 65

# %%
A=20
A
# Out:
# 20

# %%
a=100
a
# Out:
# 100

# %%
10A=20
10A
# Out:
#   File "/tmp/ipython-input-1230723613.py", line 1
#     10A=20
#      ^
# SyntaxError: invalid decimal literal

# %%
a_10= 100
a_10
# Out:
# 100

# %%
_A=30
_A
# Out:
# 30

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a1 = "Artificial Intelligence"
print(a1[11])
# Out:
# I

# %%
a1[0:4]
# Out:
# 'Arti'

# %%
a1[1:5]
# Out:
# 'rtif'

# %%
a1[:]
# Out:
# 'Artificial Intelligence'

# %%
len(a1)
# Out:
# 23
