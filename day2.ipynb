# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangrila001/miniature-carnival/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int(1.999)
# Out:
# 1

# %%
a = 10
b = 10
a is b
# Out:
# True

# %%
int(10+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-789285347.py in <cell line: 0>()
# ----> 1 int(10+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(True)
# Out:
# 1

# %%
int("10")
# Out:
# 10

# %%
float(1)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
a = 10.20
int(a)
# Out:
# 10

# %%
int("Sangrila")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2422561790.py in <cell line: 0>()
# ----> 1 int("Sangrila")
#
# ValueError: invalid literal for int() with base 10: 'Sangrila'

# %%
complex(15)
# Out:
# (15+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
id (a)
# Out:
# 11654664

# %%
id (b)
# Out:
# 11654664

# %%
a= str('10.00')
print(a)
# Out:
# 10.00

# %%
a = "Data Science"
print(id(a))
a= "Sangrila"
print(id(a))
# Out:
# 131979248193392
# 131979243215984

# %%
x = [10,20,30,40]
type(x)
# Out:
# list

# %%
b = bytes(x)
type(b)
# Out:
# bytes

# %%
c = [1000,2000]
d= bytes(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3063501523.py in <cell line: 0>()
#       1 c = [1000,2000]
# ----> 2 d= bytes(c)
#
# ValueError: bytes must be in range(0, 256)

# %%
a = "Data"
a[0:2]
# Out:
# 'Da'

# %%
x = [10,20,30,40]
b= bytes(x)
b[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2120434377.py in <cell line: 0>()
#       1 x = [10,20,30,40]
#       2 b= bytes(x)
# ----> 3 b[0]=100
#
# TypeError: 'bytes' object does not support item assignment

# %%
x = [10,20,30,40]
x[0]= 100
x
# Out:
# [100, 20, 30, 40]

# %%
x= [10,20,30,40]
b= bytearray(x)
b[0]= 100
print(b)
# Out:
# bytearray(b'd\x14\x1e(')

# %%
for i in b:
  print(i)
# Out:
# 100
# 20
# 30
# 40

# %%
t =(10,20,30,40)
type(t)
# Out:
# tuple

# %%
#original tuple
t1 = (1,2,3,)
print(id(t1))  #memory address of t1
# Out:
# 132367164022208

# %%
# concatenation creates a new tuple
t1= t1 + (4,5,6)
print(t1)
print(id(t1))
# Out:
# (1, 2, 3, 4, 5, 6)
# 132367165569440

# %%
complex(False)
# Out:
# 0j

# %%
a1 = (10,20)
a2 = ('a', 'b')
a1+a2
# Out:
# (10, 20, 'a', 'b')
