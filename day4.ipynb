# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangrila001/miniature-carnival/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_name = None
if user_name is None :
  print ("user name is not defined")
# Out:
# user name is not defined

# %%
a = 15
b = 2
print('a+b =', a+b)
print('a-b =', a-b)
print('a*b =', a*b)
print('a/b =', a/b)
print('a//b =', a//b)
print('a%b =', a%b)
print('a**b =', a**b)
# Out:
# a+b = 17
# a-b = 13
# a*b = 30
# a/b = 7.5
# a//b = 7
# a%b = 1
# a**b = 225

# %%
+

# %%
(3+3)*2+12-9%2
# Out:
# 23

# %%
9%2
# Out:
# 1

# %% [markdown]
# **Write** **the program for Maximum Of Three Numbers**

# %%
a = 10
b = 20
c = 30
if a > b and a > c:
  print(a)
elif b > a and b > c:
  print(b)
else:
  print(c)
# Out:
# 30

# %%
a = 10
b = 20
c = 30
if a>b and a>c:
  print(a)
elif b>a and b>c:
  print(b)
else:
  print(c)
# Out:
# 30

# %% [markdown]
# **Homework: Q) Write a Python Program to find Area of Circle
# **

# %%
import math
r=10 #radiur
area=math.pi*r*r
print(area)
# Out:
# 314.1592653589793
